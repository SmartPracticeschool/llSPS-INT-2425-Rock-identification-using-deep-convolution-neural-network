# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# C:\Users\prana\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\prana\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\prana\Anaconda\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import tensorflow
tensorflow.__version__
# Out:
# '1.14.0'

# %% [markdown]
# ##  Keras version 2.2.4 req if not in anaconda prompt

# %% [markdown]
# ##  Tensorflow version 1.14.0 req if not in anaconda prompt

# %% [markdown]
# 1. activate environment ==> conda activate tf
# 2. conda install tensorflow==1.14.0

# %% [markdown]
# # Colored Images

# %% [markdown]
# colored images will have 4 layers  R,G,B

# %% [markdown]
# # Convolution Neural Networks

# %% [markdown]
# ![](Lect_8_CNN_2_Layers.png)

# %% [markdown]
# ### MaxPooling Because of Spatial Invariance

# %% [markdown]
# #  --------------------------CNN-PRACTICALS-------------------------------------

# %% [markdown]
# ![](Lect_8_CNN_5_Creating_Datasets.png)

# %% [markdown]
# ### Steps To Draw A CNN

# %% [raw]
# import Req Libraries

# %% [raw]
# Preprocess the Data using Image Generator Class

# %% [raw]
# Load  Dataset and Apply image generator class preprocessing techniques to dataset

# %% [raw]
# Initialize the model

# %% [raw]
# Add convolution Layer

# %% [raw]
# Add maxpooling Layer

# %% [raw]
# Add Flattenning Layer is Considered As Input Layer

# %% [raw]
# Add Ann Hidden Layer

# %% [raw]
# Add Ann output Layer

# %% [raw]
# Configure the Learning Process

# %% [raw]
# Train The Data

# %% [raw]
# Save the model

# %% [markdown]
# ## Creation Of Dataset

# %% [raw]
# Create A Folder And Name it as Dataset Total 100 images of each Friend

# %% [raw]
# Create Test Folder
#     Friend A 30
#     Friend B 30
#     Friend C 30
# Create Train Folder
#    Friend A 70
#    Friend B 70
#    Friend C 70

# %% [raw]
# Loss Function = Categorical Cross Entropy

# %% [markdown]
# ![](Lect_8_CNN_6_Model_Building.png)

# %% [markdown]
# #  ANIMAL IMAGE CLASSIFICATION

# %% [markdown]
# ### Step 1.Import Libraries

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten

# %% [markdown]
# ### Step 2.Preprocessing  Using Data Generator

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.8,zoom_range=0.8,horizontal_flip=True) #sher= distance increase flip,etc if not able to understand
test_datagen=ImageDataGenerator(rescale=1./255) # upper options can be used but not required

# %% [markdown]
# ##### Gets Divided into 32 Batch Sizes during Training

# %% [markdown]
# ##### rescale= scaling the pictures in range 0 to 1

# %% [markdown]
# #### shear_range=put image 20% far away

# %% [markdown]
# #### zoom_range=zoom in zoom out

# %% [markdown]
# ### Step 3 Load  Dataset and Apply image generator class preprocessing techniques to dataset

# %%
x_train=train_datagen.flow_from_directory(r"C:\Users\prana\Desktop\Project S\traindata",target_size=(64,64),batch_size=32,class_mode="categorical")
x_test=test_datagen.flow_from_directory(r"C:\Users\prana\Desktop\Project S\testdata",target_size=(64,64),batch_size=32,class_mode="categorical")
# Out:
# Found 709 images belonging to 13 classes.
# Found 237 images belonging to 13 classes.

# %%
print(x_train.class_indices) #labels given to datasets
# Out:
# {'Basalt': 0, 'Conglomerate': 1, 'Dolostone': 2, 'Gabbro': 3, 'Gneiss': 4, 'Granite': 5, 'Limestone': 6, 'Marble': 7, 'Quartzite': 8, 'Rhyolite': 9, 'Sandstone': 10, 'Shale': 11, 'Slate': 12}

# %% [markdown]
# ### Step 4 Initialize The Model

# %%
model=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# ![](Lect_8_CNN_7__Step5.png)

# %% [markdown]
# activation function

# %% [markdown]
# fd=Feature Detector,input size of image,

# %% [markdown]
# ### Step 5 Add Convolution Layer

# %%
model.add(Convolution2D(128,(3,3),input_shape=(64,64,3),activation="relu"))
# Out:
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %% [markdown]
# ##### Papameters

# %% [markdown]
# #####  Number of Feature Detectors =32,Shape=3 by 3 input shape of image=(64,64,3) activation function used=relu

# %% [markdown]
# ##### Above 32 Feature Detectors of Size 3 by 3
# One Detector =>eye, other nose, third color......

# %% [markdown]
# ### Step6 Add maxpooling Layer###

# %%
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.add(Flatten()) #Input Layer Of ANN

# %% [markdown]
# ### Step 7 Add Hidden Layers

# %%
model.add(Dense(units=64,init="random_uniform",activation="relu")) # Hidden Layer
# Out:
# C:\Users\prana\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=64, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=64,init="random_uniform",activation="relu")) # Hidden Layer
# Out:
# C:\Users\prana\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=64, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=64,init="random_uniform",activation="relu")) # Hidden Layer
# Out:
# C:\Users\prana\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=64, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.add(Dense(units=13,init="random_uniform",activation="softmax")) # Output Layer
# Out:
# C:\Users\prana\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=13, activation="softmax", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
model.compile(loss="categorical_crossentropy",optimizer="Adam",metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ### Train Machine

# %% [raw]
# Found 2856 images belonging to 87 classes.
# Found 363 images belonging to 87 classes.

# %%
model.fit_generator(x_train,steps_per_epoch=709/32,epochs=5000,validation_data=x_test,validation_steps=237/32)
# Out:
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\prana\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/5000
# 23/22 [===============================] - 13s 550ms/step - loss: 2.5639 - acc: 0.0925 - val_loss: 2.5572 - val_acc: 0.0802
# Epoch 2/5000
# 23/22 [===============================] - 9s 382ms/step - loss: 2.5514 - acc: 0.0953 - val_loss: 2.5481 - val_acc: 0.0802
# Epoch 3/5000
# 23/22 [===============================] - 9s 386ms/step - loss: 2.5275 - acc: 0.0980 - val_loss: 2.4977 - val_acc: 0.1139
# Epoch 4/5000
# ...

# %% [raw]
# steps_per_epoch=2856/32
# validation_steps==373/32
# IN cnn Training And Testing Will Happen Simmaltoneously

# %%
model.save("RockIdentification.h5")

# %%
print(history.history.keys())
